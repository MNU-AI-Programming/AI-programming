# %% [markdown]
# # AI활용프로그래밍 Week 3 실습 노트북
# ## 변수 · 자료형 · 연산자 (With AI 연습)
#
# 본 노트북은 Week 3 강의자료 기반으로 제작되었습니다. fileciteturn2file0
# 실행하면서 기본 문법을 확실히 다집니다.
#
# ---
# ### 🎯 오늘 목표
# 1. 변수의 개념을 이해한다.
# 2. 기본 자료형(int/float/str/bool)을 구분한다.
# 3. 산술·비교·논리 연산자를 사용한다.
# 4. LLM에게 코드 생성→검증→개선 요청을 해본다.

# %% [markdown]
# ## 1. 변수란 무엇인가?

# %% [markdown]
# 변수는 값을 저장해두고 이름으로 다시 사용하게 해주는 공간입니다.
#
# 예:
# tax_rate = 0.1
# 세율이 바뀌면 한 곳만 수정하면 됩니다.

# %%
name = "Kim"
age = 20

print(name)
print(age)

age = age + 1
print("next:", age)

# %% [markdown]
# 👉 '=' 는 수학의 같다(=)가 아니라 '할당' 입니다.

# %% [markdown]
# ## 2. 변수 이름 규칙

# %% [markdown]
# ✔ 영문, 숫자, _(언더스코어) 사용 가능
# ✔ 숫자로 시작 불가
# ✔ 예약어(if, for 등) 사용 불가
# ✔ 의미 있는 이름 권장 (예: total_score)

# %% [markdown]
# ## 3. 기본 자료형

# %%
x = 10
y = 3.14
s = "10"
flag = True

print(type(x))
print(type(y))
print(type(s))
print(type(flag))

# %% [markdown]
# ✔ input()은 항상 문자열(str)
# ✔ 숫자로 계산하려면 형 변환 필요

# %% [markdown]
# ## 4. 형 변환 & 입력

# %%
a = int(input("a: "))
b = int(input("b: "))

print("sum:", a + b)
print("avg:", (a + b) / 2)

# %% [markdown]
# 👉 b가 0이면 나눗셈에서 오류 발생 가능 (Week4에서 해결)

# %% [markdown]
# ## 5. 산술 연산자

# %%
n = 17

print("몫:", n // 5)
print("나머지:", n % 5)
print("거듭제곱:", 2 ** 3)

# %% [markdown]
# 👉 단위 변환에서 몫/나머지는 매우 자주 사용됩니다.

# %% [markdown]
# ## 6. 비교 & 논리 연산자

# %%
age = 19
has_id = True

is_adult = age >= 20
can_enter = (age >= 18) and has_id

print(is_adult)
print(can_enter)

# %% [markdown]
# 👉 결과는 항상 bool(True/False) 입니다.

# %% [markdown]
# ## 7. 실습 1: 합계/평균 계산기

# %% [markdown]
# 문제:
# 정수 2개를 입력받아 합계(sum)와 평균(avg)을 출력하세요.
# 조건: 평균은 실수로 출력

# %%
# TODO: 합계/평균 계산기 작성

# %% [markdown]
# ## 8. 실습 2: 영수증 출력 (f-string 사용)

# %% [markdown]
# 문제:
# 상품명, 가격, 수량을 입력받아 다음 형식으로 출력
#
# 예:
# 사과 1000원 × 3개 → 총액 3000원

# %%
# TODO: 영수증 프로그램 작성

# %% [markdown]
# ## 9. 실습 3: 단위 변환기

# %% [markdown]
# 문제:
# cm를 입력받아 inch로 변환 (1 inch = 2.54 cm)

# %%
# TODO: cm → inch 변환기 작성

# %% [markdown]
# ## 10. With AI 프롬프트 템플릿

# %% [markdown]
# 역할: 너는 파이썬 튜터야.
# 목표: 아래 문제를 파이썬으로 풀어줘.
# 입력 예: a=3, b=5
# 출력 예: sum=8, avg=4.0
# 제약: 변수/자료형/연산자만 사용 (조건문 X)
# 요청: 코드 + 줄별 설명 + 테스트 3개

# %% [markdown]
# 👉 ChatGPT에 입력 후, 실행해보고 수정하세요.

# %% [markdown]
# ## 11. 미니 퀴즈

# %% [markdown]
# 1) input() 반환 자료형은?
# 2) 17 // 5 결과는?
# 3) "10" + "3" 결과는?
# 4) 3 < 5 and 2 > 10 결과는?
# 5) 변수 이름으로 사용할 수 없는 것은? (my_var / 2nd / score)

# %% [markdown]
# ## 12. 과제 안내

# %% [markdown]
# 기본:
# - 길이 변환기 + 온도 변환기 완성
# - 테스트 5개
#
# 도전:
# - 거스름돈 계산기 (몫/나머지 활용)
#
# 제출:
# - .py 파일 1개
# - 실행 결과 캡처 1장
# - 사용한 프롬프트 2개 주석 첨부

# %% [markdown]
# ## 오늘 정리

# %% [markdown]
# ✔ 변수는 이름표(label)
# ✔ input은 문자열 반환
# ✔ 몫/나머지는 단위 변환에 자주 사용
# ✔ LLM은 실행→검증→수정이 핵심
