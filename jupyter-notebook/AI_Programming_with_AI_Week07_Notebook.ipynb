# %% [markdown]
# # AI활용프로그래밍 Week 7 실습 노트북
# ## 튜플 · 딕셔너리 · 집합 (자료구조 확장 + With AI 연습)
#
# 본 노트북은 Week 7 강의자료 기반으로 제작되었습니다. fileciteturn3file0
#
# ---
# ### 🎯 오늘 목표
# 1. tuple, dict, set의 특징을 설명할 수 있다.
# 2. 기본 문법과 메서드를 사용할 수 있다.
# 3. 문제에 맞는 자료구조를 선택할 수 있다.
# 4. LLM과 함께 설계 → 구현 → 개선 과정을 실습한다.

# %% [markdown]
# ## 1. 튜플(tuple) 기초

# %%
point = (10, 20)

x, y = point
print("x:", x)
print("y:", y)

# swap (값 교환)
a, b = 1, 2
a, b = b, a
print("a:", a, "b:", b)

# %% [markdown]
# ✔ 튜플은 수정 불가(immutable)
# ✔ 패킹 / 언패킹 자주 사용
# ✔ 함수에서 여러 값 반환할 때 유용

# %% [markdown]
# ## 2. 튜플 vs 리스트

# %% [markdown]
# 리스트: 수정 가능
# 튜플: 고정된 값 묶음
#
# 👉 '값이 바뀌어야 하는가?'가 선택 기준

# %% [markdown]
# ## 3. 딕셔너리(dict) 기초

# %%
score = {"Kim": 90, "Lee": 80}

print(score["Kim"])

score["Park"] = 70   # 추가
score["Lee"] = 85    # 수정

print(score)

# %% [markdown]
# ✔ key-value 구조
# ✔ 키가 없으면 KeyError 발생
# ✔ get() 사용 권장

# %%
score = {"Kim": 90}
print(score.get("Lee", 0))

for name, s in score.items():
    print(name, s)

# %% [markdown]
# ## 4. 단어 빈도수 세기 (대표 예제)

# %%
text = "banana"
freq = {}

for ch in text:
    freq[ch] = freq.get(ch, 0) + 1

print(freq)

# %% [markdown]
# ## 5. 집합(set) 기초

# %%
nums = [1, 1, 2, 3, 3]
s = set(nums)

print("중복 제거:", s)

print("정렬:", sorted(s))

# %% [markdown]
# ## 6. 집합 연산

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print("합집합:", a | b)
print("교집합:", a & b)
print("차집합:", a - b)

# %% [markdown]
# ✔ set은 순서가 없음
# ✔ 중복 제거 / 포함 검사에 강함

# %% [markdown]
# ## 7. 자료구조 선택 가이드

# %% [markdown]
# list: 순서 O, 수정 O
# tuple: 순서 O, 수정 X
# dict: key 기반 조회
# set: 중복 X, 집합 연산
#
# 👉 문제의 '성격'에 따라 선택

# %% [markdown]
# ## 8. 실습 1: 연락처 관리 (dict 사용)

# %% [markdown]
# 기능:
# - add(이름, 번호)
# - find(이름)
# - list(전체 출력)
#
# 정책:
# 같은 이름이 있으면 '수정'하도록 구현

# %%
# TODO: 연락처 관리 프로그램 작성

# %% [markdown]
# ## 9. 실습 2: 단어 빈도 TOP 3

# %% [markdown]
# 문장을 입력받아 단어 빈도수를 구하고
# 가장 많이 나온 단어 TOP 3 출력

# %%
# TODO: 단어 빈도 분석 프로그램 작성

# %% [markdown]
# ## 10. 실습 3: 로또 번호 검사 (set 활용)

# %% [markdown]
# 사용자 입력 6개 (중복 없이)
# 당첨 번호와 교집합 개수 계산

# %%
# TODO: 로또 검사 프로그램 작성

# %% [markdown]
# ## 11. With AI 프롬프트 템플릿

# %% [markdown]
# 역할: 파이썬 설계 코치
# 문제: 학생 이름과 점수를 저장하고 이름으로 조회
# 입력 예: Kim 90, Lee 80
# 질문: list/tuple/dict/set 중 무엇이 적절? 이유는?
# 그 후: 코드 작성 + 테스트 3개

# %% [markdown]
# ## 12. 미니 퀴즈

# %% [markdown]
# 1) tuple의 가장 큰 특징은?
# 2) dict에서 키가 없을 때 안전하게 값 얻는 방법은?
# 3) set이 중복 제거에 좋은 이유는?
# 4) (a,b) = (b,a)가 가능한 이유는?
# 5) list vs dict 선택 기준 1가지?

# %% [markdown]
# ## 13. 과제 안내

# %% [markdown]
# 기본:
# - 연락처 관리 프로그램 제출
#
# 도전:
# - 단어 빈도 TOP-N + 동점 처리
#
# 제출:
# - .py 파일 1개
# - 실행 캡처 1장
# - 사용한 프롬프트 2개 + 선택 이유 기록

# %% [markdown]
# ## 오늘 정리

# %% [markdown]
# ✔ tuple: 변경 불가
# ✔ dict: key-value 매핑
# ✔ set: 중복 제거 & 집합 연산
# ✔ 자료구조는 문제 성격에 따라 선택
