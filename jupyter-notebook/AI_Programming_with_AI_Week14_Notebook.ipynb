# %% [markdown]
# # AI활용프로그래밍 Week 14 — 프로젝트 제출 템플릿
#
# 이 노트북을 **내 드라이브로 복사해** 내용을 채워 넣으면 그대로 제출물이 됩니다.
#
# - 코랩 메뉴 **[파일] → [드라이브에 사본 저장]**
# - 제목을 `기말프로젝트_홍길동` 으로 바꾸세요.
#
# > 📌 **이 안내 칸은 지우고 시작하세요.** 아래 회색 칸부터가 제출물입니다.
#
# ---
#
# ### 채우는 순서
# 1. 아래 「프로젝트 소개」 칸을 채웁니다.
# 2. 코드 칸에 내 프로그램을 넣고 **실행해 결과를 남깁니다.**
# 3. 「잘 안 되는 경우」를 직접 넣어 봅니다.
# 4. 「AI 활용 기록」을 씁니다.
# 5. **[런타임] → [모두 실행]** 이 처음부터 끝까지 되는지 확인합니다.
# 6. 오른쪽 위 [공유] → 링크 권한을 바꿔 링크를 제출합니다.
#
# ### 제출 전 마지막 점검
# - [ ] [모두 실행] 이 한 번에 되는가
# - [ ] 실행 결과가 저장된 채로 남아 있는가
# - [ ] AI 활용 기록을 하나 이상 적었는가
# - [ ] 링크 권한을 '링크가 있는 모든 사용자(뷰어)'로 바꿨는가
# - [ ] 발표가 3~5분 안에 끝나는가

# %% [markdown]
# ---
# # 프로젝트 제목
#
# ## 한 줄 소개
#
#
# ## 왜 만들었나
# - 어떤 불편을 풀고 싶었는지:
#
# ## 무엇을 할 수 있나
# - 기능 1:
# - 기능 2:
# - 기능 3:
#
# ## 어떻게 쓰나
# - 위에서부터 셀을 실행하세요.
# - 입력 예시:

# %% [markdown]
# ---
# ## 1. 준비
#
# 필요한 도구를 가져오고, 읽을 데이터가 있으면 여기서 읽습니다.
#
# > 파일을 쓴다면 드라이브에 저장해 두세요. `/content` 에 만든 파일은 사라집니다(9주차).

# %%
# 예) import pandas as pd
#     import matplotlib.pyplot as plt

# 그래프에 한글을 쓴다면 (11주차)
# !apt-get -qq -y install fonts-nanum
# import matplotlib.font_manager as fm
# p = "/usr/share/fonts/truetype"
# fm.fontManager.addfont(p + "/nanum/NanumGothic.ttf")
# plt.rc("font", family="NanumGothic")
# plt.rc("axes", unicode_minus=False)

# %% [markdown]
# ---
# ## 2. 내 프로그램
#
# 기능마다 칸을 나누면 발표할 때 보여주기 좋습니다.
# 각 칸 위에 **무엇을 하는 칸인지** 한 줄씩 적어 두세요.

# %%
# 기능 1:

# %%
# 기능 2:

# %%
# 기능 3:

# %% [markdown]
# ---
# ## 3. 실행해 보기
#
# **넣을 값을 미리 정해 두고** 실행하세요. 발표에서 그대로 보여줄 부분입니다.

# %%
# 정상적인 입력으로 실행

# %% [markdown]
# ---
# ## 4. 잘 안 되는 경우
#
# 빈 값, 0, 아주 큰 값, 숫자 대신 글자 — 직접 넣어 보고 어떻게 되는지 적으세요.
#
# | 넣어 본 값 | 어떻게 됐나 | 막았나 |
# |---|---|---|
# |  |  |  |
# |  |  |  |
# |  |  |  |

# %%
# 잘 안 될 것 같은 값으로 실행해 보기

# %% [markdown]
# ---
# ## 5. AI 활용 기록
#
# 쓴 만큼 적으세요. 하나만 있어도 괜찮습니다.
# **'내가 고친 것'이 비어 있으면 안 됩니다.**
#
# ### AI 활용 기록 1
#
# **프롬프트**
# > (AI에게 무엇을 어떻게 물었는지 그대로)
#
# **받은 답 요약**
# -
#
# **내가 고친 것**
# -
#
# **검증**
# - (직접 실행해 무엇을 확인했는지, 숫자나 결과로)
#
# ### AI 활용 기록 2
#
# **프롬프트**
# >
#
# **받은 답 요약**
# -
#
# **내가 고친 것**
# -
#
# **검증**
# -

# %% [markdown]
# ---
# ## 6. 배운 점과 다음에 하고 싶은 것
#
# - 가장 오래 붙잡았던 문제:
# - 어떻게 풀었나:
# - 다음에 더 만든다면:

# %% [markdown]
# ---
# ## 7. 발표 대본 (1분)
#
# 발표 직전에 소리 내어 한 번 읽어 보세요.
#
# - **0:00** 제목과 한 줄 소개:
# - **0:10** 왜 만들었나:
# - **0:30** 기능 세 개:
# - **1:00** 시연에서 볼 것:
# - **2:00** AI를 어디에 썼나:
# - **2:30** 배운 점:
#
# **예상 질문과 내 답**
# - Q:
# - A:
